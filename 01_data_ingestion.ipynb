# %%
import pandas as pd
df = pd.read_csv('/Workspace/Users/yaminibhole20@gmail.com/Databricks_Genie_Rag_assistant/Data_Ingestion/employees.csv')

spark_df = spark.createDataFrame(df)
spark_df.write.mode("overwrite").saveAsTable('genie.demo.employees')
display(spark_df)

# %%
spark.sql("SELECT * FROM genie.demo.employees").show()
